# %%
import numpy as np
import pandas as pd
import random as rd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import time

from revice import crossover, find_parents_ts, generation, initialization, mutation, fitting

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(cancer['data'], columns=cancer['feature_names'])
label = cancer['target']

X_train, X_test, y_train, y_test = train_test_split(df, label, test_size=.3)

# %%
a, b = generation(size_of_population=100, n_feat=30, generation=5, X_train=X_train, X_test=X_test, y_train= y_train, y_test=y_test)
# Out:
# --> Generation: #, 1
#
# --> Family: #, 1
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9473684210526315]
# Obj Val for Mutated Child #2 at Generation #1 : [0.9415204678362573]
#
# --> Family: #, 2
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9707602339181286]
# Obj Val for Mutated Child #2 at Generation #1 : [0.9122807017543859]
#
# --> Family: #, 3
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9590643274853801]
# Obj Val for Mutated Child #2 at Generation #1 : [0.935672514619883]
#
# --> Family: #, 4
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9707602339181286]
# Obj Val for Mutated Child #2 at Generation #1 : [0.9415204678362573]
#
# --> Family: #, 5
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9473684210526315]
# Obj Val for Mutated Child #2 at Generation #1 : [0.9239766081871345]
#
# --> Family: #, 6
#
# Obj Val for Mutated Child #1 at Generation #1 : [0.9181286549707602]
# ...
